# %% [markdown]
# # Notebook 1: OpenAI Agents SDK — Basics
#
# **What you'll learn:** What is the Agents SDK, why it exists, its core primitives, and your first agent in 5 lines.
#
# ---
#
# ## What is an AI Agent?
#
# An **AI Agent** is NOT just a chatbot. It is:
#
# ```
# Agent = LLM + Instructions + Tools + Decision-Making Loop
# ```
#
# A chatbot answers questions. An agent **takes actions**, **makes decisions**, and **completes tasks autonomously**.
#
# ### Real-World Analogy
# - **Chatbot** = A librarian who answers your questions
# - **Agent** = A personal assistant who books flights, sends emails, checks weather, and plans your day
#
# ---
#
# ## Why OpenAI Agents SDK?
#
# | Feature | Raw LLM API | LangChain | **Agents SDK** |
# |---|---|---|---|
# | Complexity | Manual everything | Heavy abstractions | **Minimal primitives** |
# | Learning Curve | Low (but manual) | Steep | **Gentle** |
# | Production Ready | DIY | Yes | **Yes** |
# | Tool Calling | Manual JSON | Chain-based | **Decorator-based** |
# | Multi-Agent | Build yourself | Complex graphs | **Built-in handoffs** |
# | Provider Lock-in | OpenAI only | Any | **Any (100+ LLMs)** |
#
# The SDK evolved from OpenAI's experimental **Swarm** project into a production-grade framework.
#
# ---
#
# ## The 4 Core Primitives
#
# The entire SDK is built on just **4 concepts**:
#
# ```
# 1. Agent        → The brain (LLM + instructions + tools)
# 2. Runner       → The executor (runs the agent loop)
# 3. Tools        → The hands (functions the agent can call)
# 4. Handoffs     → The delegation (agent-to-agent transfer)
# ```
#
# That's it. No graphs, no nodes, no edges, no state machines.

# %% [markdown]
# ## Installation

# %%
# Install the SDK
# uv add openai-agents

# %% [markdown]
# ## Setup API Key
#
# By default, the SDK uses OpenAI. Set your key:

# %%
import os

# Option 1: Set directly (for learning only — never commit real keys!)
os.environ["MODEL_KEY"] = "ollama"

# Option 2: Use .env file (recommended)
# uv add python-dotenv
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ---
#
# ## Your First Agent — Hello World

# %%
from agents import Agent, Runner

agent = Agent(
    name="Greeter",
    instructions="You are a friendly assistant. Be concise.",
)

result = await Runner.run(agent, "Hello! What can you do?")
print(result.final_output)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[1], line 8
#       1 from agents import Agent, Runner
#       3 agent = Agent(
#       4     name="Greeter",
#       5     instructions="You are a friendly assistant. Be concise.",
#       6 )
# ----> 8 result = await Runner.run(agent, "Hello! What can you do?")
#       9 print(result.final_output)
#
# File c:\Users\zaidy\Desktop\Agent-lens\.venv\Lib\site-packages\agents\run.py:223, in Runner.run(cls, starting_agent, input, context, max_turns, hooks, run_config, error_handlers, previous_response_id, auto_previous_response_id, conversation_id, session)
#     173 """
#     174 Run a workflow starting at the given agent.
#     175
#    (...)    219     type of the output.
#     220 """
#     222 runner = DEFAULT_AGENT_RUNNER
# --> 223 return await runner.run(
#     224     starting_agent,
#     225     input,
#     226     context=context,
#     227     max_turns=max_turns,
#     228     hooks=hooks,
#     229     run_config=run_config,
#     230     error_handlers=error_handlers,
#     231     previous_response_id=previous_response_id,
#     232     auto_previous_response_id=auto_previous_response_id,
#     233     conversation_id=conversation_id,
#     234     session=session,
#     235 )
#
# File c:\Users\zaidy\Desktop\Agent-lens\.venv\Lib\site-packages\agents\run.py:1067, in AgentRunner.run(self, starting_agent, input, **kwargs)
#    1065         raise
#    1066 else:
# -> 1067     turn_result = await model_task
#    1069 input_guardrail_results.extend(sequential_results)
#    1070 input_guardrail_results.extend(parallel_results)
#
# File c:\Users\zaidy\Desktop\Agent-lens\.venv\Lib\site-packages\agents\run_internal\run_loop.py:1549, in run_single_turn(agent, all_tools, original_input, generated_items, hooks, context_wrapper, run_config, should_run_agent_start_hooks, tool_use_tracker, server_conversation_tracker, session, session_items_to_rewind, reasoning_item_id_policy)
#    1546 else:
#    1547     input = _prepare_turn_input_items(original_input, generated_items, reasoning_item_id_policy)
# -> 1549 new_response = await get_new_response(
#    1550     agent,
#    1551     system_prompt,
#    1552     input,
#    1553     output_schema,
#    1554     all_tools,
#    1555     handoffs,
#    1556     hooks,
#    1557     context_wrapper,
#    1558     run_config,
#    1559     tool_use_tracker,
#    1560     server_conversation_tracker,
#    1561     prompt_config,
#    1562     session=session,
#    1563     session_items_to_rewind=session_items_to_rewind,
#    1564 )
#    1566 return await get_single_step_result_from_response(
#    1567     agent=agent,
#    1568     original_input=original_input,
#    (...)   1577     tool_use_tracker=tool_use_tracker,
#    1578 )
#
# File c:\Users\zaidy\Desktop\Agent-lens\.venv\Lib\site-packages\agents\run_internal\run_loop.py:1608, in get_new_response(agent, system_prompt, input, output_schema, all_tools, handoffs, hooks, context_wrapper, run_config, tool_use_tracker, server_conversation_tracker, prompt_config, session, session_items_to_rewind)
#    1605 if isinstance(filtered.input, list):
#    1606     filtered.input = deduplicate_input_items_preferring_latest(filtered.input)
# -> 1608 model = get_model(agent, run_config)
#    1609 model_settings = agent.model_settings.resolve(run_config.model_settings)
#    1610 model_settings = maybe_reset_tool_choice(agent, tool_use_tracker, model_settings)
#
# File c:\Users\zaidy\Desktop\Agent-lens\.venv\Lib\site-packages\agents\run_internal\turn_preparation.py:132, in get_model(agent, run_config)
#     129 elif isinstance(agent.model, Model):
#     130     return agent.model
# --> 132 return run_config.model_provider.get_model(agent.model)
#
# File c:\Users\zaidy\Desktop\Agent-lens\.venv\Lib\site-packages\agents\models\multi_provider.py:216, in MultiProvider.get_model(self, model_name)
#     213 # Bare model names are always delegated directly to the OpenAI provider. That provider can
#     214 # still point at an OpenAI-compatible endpoint via ``base_url``.
#     215 if model_name is None:
# --> 216     return self.openai_provider.get_model(None)
#     218 prefix, stripped_model_name = self._get_prefix_and_model_name(model_name)
#     219 if prefix is None:
#
# File c:\Users\zaidy\Desktop\Agent-lens\.venv\Lib\site-packages\agents\models\openai_provider.py:199, in OpenAIProvider.get_model(self, model_name)
#     197     if loop_cache is not None and (cached_model := loop_cache.get(cache_key)):
#     198         return cached_model
# --> 199 client = self._get_client()
#     200 model: Model
#     202 if not self._use_responses:
#
# File c:\Users\zaidy\Desktop\Agent-lens\.venv\Lib\site-packages\agents\models\openai_provider.py:102, in OpenAIProvider._get_client(self)
#     100 def _get_client(self) -> AsyncOpenAI:
#     101     if self._client is None:
# --> 102         self._client = _openai_shared.get_default_openai_client() or AsyncOpenAI(
#     103             api_key=self._stored_api_key or _openai_shared.get_default_openai_key(),
#     104             base_url=self._stored_base_url or os.getenv("OPENAI_BASE_URL"),
#     105             websocket_base_url=(
#     106                 self._stored_websocket_base_url or os.getenv("OPENAI_WEBSOCKET_BASE_URL")
#     107             ),
#     108             organization=self._stored_organization,
#     109             project=self._stored_project,
#     110             http_client=shared_http_client(),
#     111         )
#     113     return self._client
#
# File c:\Users\zaidy\Desktop\Agent-lens\.venv\Lib\site-packages\openai\_client.py:514, in AsyncOpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     512     api_key = os.environ.get("OPENAI_API_KEY")
#     513 if api_key is None:
# --> 514     raise OpenAIError(
#     515         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     516     )
#     517 if callable(api_key):
#     518     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
# OPENAI_API_KEY is not set, skipping trace export

# %% [markdown]
# ### Breaking it down:
#
# ```python
# Agent(name, instructions)   # WHO the agent is
# Runner.run_sync(agent, input) # RUN the agent with user input
# result.final_output           # GET what the agent produced
# ```
#
# **That's the entire mental model.** Everything else builds on this.

# %% [markdown]
# ---
#
# ## Async Version (For Jupyter Notebooks)
#
# `Runner.run_sync()` doesn't work inside Jupyter because Jupyter already has an event loop running.
# Use `await Runner.run()` instead:

# %%
from agents import Agent, Runner

agent = Agent(
    name="Greeter",
    instructions="You are a friendly assistant. Be concise.",
    # model="gpt-5.4-mini"
)

# In Jupyter, use await directly (no asyncio.run needed)
result = await Runner.run(agent, "What is the capital of Pakistan?")
print(result.final_output)

# %% [markdown]
# ---
#
# ## Understanding the Result Object
#
# The `RunResult` object contains much more than just the output:

# %%
from agents import Agent, Runner

agent = Agent(name="Analyst", instructions="You analyze topics briefly.")

result = await Runner.run(agent, "Why is Python popular for AI?")

# The key properties of RunResult:
print("=" * 50)
print(f"Final Output:  {result.final_output[:100]}...")   # The text response
print(f"Last Agent:    {result.last_agent.name}")          # Which agent finished
print(f"New Items:     {len(result.new_items)}")           # Items generated during run
print(f"Raw Responses: {len(result.raw_responses)}")       # Raw LLM responses
print("=" * 50)

# %% [markdown]
# ---
#
# ## The Agent Loop — How It Actually Works
#
# When you call `Runner.run()`, here's what happens internally:
#
# ```
# ┌─────────────────────────────────────────────┐
# │           Runner.run(agent, input)          │
# │                                             │
# │  ┌──────────────────────────────────────┐   │
# │  │ 1. Send input + instructions to LLM  │   │
# │  │ 2. LLM responds                      │   │
# │  │ 3. Check response:                   │   │
# │  │    ├─ Final output? → RETURN result  │   │
# │  │    ├─ Tool call?    → Execute tool,  │   │
# │  │    │                  loop back to 1 │   │
# │  │    └─ Handoff?      → Switch agent,  │   │
# │  │                       loop back to 1 │   │
# │  └──────────────────────────────────────┘   │
# │                                             │
# │  This loop IS the "agentic" behavior.       │
# │  The LLM DECIDES what to do next.           │
# └─────────────────────────────────────────────┘
# ```
#
# **Key insight:** The agent doesn't just answer — it enters a **reasoning loop** where it can call tools, get results, reason again, and repeat until done.

# %% [markdown]
# ---
#
# ## Multi-Turn Conversations
#
# Agents can maintain conversation context across turns using `to_input_list()`:

# %%
from agents import Agent, Runner

agent = Agent(
    name="Tutor",
    instructions="You are a Python tutor. Be concise. Remember context from previous messages."
)

# Turn 1
result = await Runner.run(agent, "What is a list in Python?")
print(f"Turn 1: {result.final_output}\n")

# Turn 2 — carry conversation history forward
new_input = result.to_input_list() + [{"role": "user", "content": "How do I sort one?"}]
result = await Runner.run(agent, new_input)
print(f"Turn 2: {result.final_output}\n")

# Turn 3
new_input = result.to_input_list() + [{"role": "user", "content": "What about reverse sort?"}]
result = await Runner.run(agent, new_input)
print(f"Turn 3: {result.final_output}")

# %% [markdown]
# ### Key Pattern:
# ```python
# # This is how you maintain conversation memory:
# new_input = previous_result.to_input_list() + [{"role": "user", "content": "next message"}]
# result = await Runner.run(agent, new_input)
# ```

# %% [markdown]
# ---
#
# ## 3 Ways to Run an Agent
#
# | Method | Use Case | Async? |
# |---|---|---|
# | `Runner.run()` | Jupyter, async apps, FastAPI | Yes |
# | `Runner.run_sync()` | Scripts, CLI tools | No |
# | `Runner.run_streamed()` | Real-time UIs, streaming | Yes |

# %%
from agents import Agent, Runner

agent = Agent(name="Streamer", instructions="Explain briefly.")

# Streaming — see tokens as they arrive
result = Runner.run_streamed(agent, "What is machine learning in 2 sentences?")

async for event in result.stream_events():
    if event.type == "raw_response_event" and hasattr(event.data, 'delta'):
        print(event.data.delta, end="", flush=True)

print(f"\n\n--- Final: {result.final_output}")

# %% [markdown]
# ---
#
# ## Exercise: Build Your First Agent
#
# Create an agent that acts as a **Lahore travel guide**. Ask it 3 questions in a multi-turn conversation.

# %%
# YOUR CODE HERE
# Hint:
# 1. Create Agent with name="Lahore Guide" and good instructions
# 2. Run it with a question about Lahore
# 3. Use to_input_list() to continue the conversation

# %% [markdown]
# ---
#
# ## Summary — What You Learned
#
# | Concept | Code |
# |---|---|
# | Create an agent | `Agent(name, instructions)` |
# | Run async | `await Runner.run(agent, input)` |
# | Run sync | `Runner.run_sync(agent, input)` |
# | Run streaming | `Runner.run_streamed(agent, input)` |
# | Get output | `result.final_output` |
# | Continue conversation | `result.to_input_list() + [new_msg]` |
#
# **Next:** Notebook 2 — Creating Proper Agents with instructions, output types, and model settings.
